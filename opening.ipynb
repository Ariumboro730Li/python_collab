# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariumboro730Li/python_collab/blob/main/opening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10000
sx = np.zeros(N)
sy = np.zeros(N)

for i in range(1,N):
  ## Generate a random number
  k = np.random.randint(1,4)

  ## update the x and y point
  sx[i] = sx[i-1]/2 + k-1
  sy[i] = sy[i-1]/2

  if k == 2:
    sy[i] += 2

plt.plot(sx,sy,'k.',markersize=1)
plt.title('Sierpinski Triangle')
plt.axis('off')
plt.show()

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week

print(seconds_in_a_day)
print(seconds_in_a_week)
# Out:
# 86400
# 604800

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
